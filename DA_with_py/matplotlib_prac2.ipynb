# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y1=[20,23,35,65,70]
y2=[30,40,50,70,80]

plt.plot(x,y1,label='First')
plt.plot(x,y2,label='Second')
plt.legend()
plt.grid()
plt.show()

# %%
import random
data=[3, 4, 6, 8, 8, 1, 8, 3, 7, 2]

print(data)
plt.hist(data,bins=4,edgecolor='black')
# Out:
# [3, 4, 6, 8, 8, 1, 8, 3, 7, 2]
# (array([2., 2., 1., 1., 4.]),
#  array([1. , 2.4, 3.8, 5.2, 6.6, 8. ]),
#  <BarContainer object of 5 artists>)
