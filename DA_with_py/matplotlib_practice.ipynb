# %%
import matplotlib.pyplot as plt
data=[7, 5, 2, 11, 3, 5, 1, 2, 8, 5]
plt.hist(data,bins=5,color='orange',edgecolor='black')
# Out:
# (array([3., 1., 3., 2., 1.]),
#  array([ 1.,  3.,  5.,  7.,  9., 11.]),
#  <BarContainer object of 5 artists>)

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[100,112,165,67,89]
plt.plot(x,y,marker='o')

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[100,112,165,67,89]
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>
